# %%
from webUtils import getWebData, getHTML
from ioUtils import getFile, saveFile
from fsUtils import isFile
from time import sleep
from pandas import DataFrame

# %% [markdown]
# # Download Standings Website to Get Full List of Teams

# %%
url = "https://www.espn.com/mens-college-basketball/standings"
savename = "data/standings.p"
getWebData(base=url, savename=savename, useSafari=False)

# %% [markdown]
# ## Parse Standings Data

# %%
teamsInfo = {}
bsdata = getHTML('data/standings.p')


tables = bsdata.findAll("table")
for table in tables:
    trs = table.findAll("tr")    
    for tr in trs:
        tds = tr.findAll("td")
        if len(tds) == 1:
            #print(tds)
            refs = tds[0].findAll("a")
            if len(refs) == 3:
                primeRef = refs[2]
                teamName = primeRef.text
                href     = primeRef.attrs['href']
                href     = "".join(["http://www.espn.com", href])
                teamID   = href.split("/")
                try:
                    int(teamID[-2])
                except:
                    raise ValueError("Cannot get team ID for {0} -> {1}".format(teamName, href))
                teamsInfo[teamID[-2]] = {"Name": teamName, "Ref": href}

print("Found {0} Division I Teams".format(len(teamsInfo)))
saveFile(idata=teamsInfo, ifile="data/teams.p", debug=True)

# %% [markdown]
# # Download Team Sites

# %%
teamsInfo = getFile("data/teams.p")
for teamID, teamData in teamsInfo.items():
    name = teamData["Name"]
    href = teamData["Ref"]
    print("Downloading {0} Data".format(name))
    url = href    
    savename = "data/teams/{0}.p".format(name)
    if not isFile(savename):
        try:
            getWebData(base=url, savename=savename, useSafari=False)
            sleep(2)
        except:
            print("Trouble with {0}".format(name))
            sleep(1)

# %% [markdown]
# ## Parse Team Site Data

# %%
def getTeamID(ref, shift):    
    try:
        teamID = ref.split("/")[shift]
    except:
        raise ValueError("Cannot parse team ID [{0}]".format(ref))
    return teamID


def getGameID(ref):
    try:
        gameID = int(ref.split("=")[-1])
    except:
        raise ValueError("Cannot parse game ID [{0}]".format(ref))
    return gameID
        

def parseGameOpp(gameOpp):
    img = gameOpp.find("img")
    if img is None:
        return [None]
    
    if img is None:
        raise ValueError("Cannot find opponent logo")
    src = img.attrs['src']
    try:
        vals = src.split(".png")
    except:
        raise ValueError("Cannot parse opponent src")
    
    opp = getTeamID(vals[0], -1)
        
    try:
        int(opp)
    except:
        raise ValueError("Opponent is not an integer [{0}]".format(opp))
        
    return opp
        
        

def parseGameInfo(gameInfo):
    isHomeGame = None
    text = gameInfo.text
    if text.startswith("@ "):
        isHomeGame = False
        opp = text[1:].strip()
    elif text.startswith("vs "):
        isHomeGame = True
        opp = text[2:].strip()
    else:
        raise ValueError("Not sure how to parse game Info [{0}]".format(gameInfo))
        
    return {"IsHomeGame": isHomeGame, "Opponent": opp}
        
        
        
def parseGameResult(gameResult):
    isWin = None
    text = gameResult.text
    if text == "L":
        isWin = False
    elif text == "W":
        isWin = True
    elif len(text) == 0:
        isWin = None
    else:
        raise ValueError("Not sure how to parse game Result [{0}]".format(gameResult))
        
    return {"IsWin": isWin, "IsDone": True}

        
    
def parseGameScore(gameScore, info, result, opp):
    isDone     = result['IsDone']    
    if isDone is False:
        return {"Team Score": None, "Opp Score": None}

    isHomeGame = info['IsHomeGame']

    text = gameScore.text
    scores = text.split('-')
    if len(scores) == 2:
        try:
            scores = [int(x) for x in scores]
        except:
            raise ValueError("Scores are not integers [{0}]".format(text))
    else:
        if text == "SUSP":
            result["IsDone"] = None
            return {"Team Score": None, "Opp Score": None}
        else:
            raise ValueError("Not sure how to parse scores [{0}]".format(text))
        
    isWin = result["IsWin"]
    if isWin is True:
        teamScore = max(scores)
        oppScore  = min(scores)
    elif isWin is False:
        teamScore = min(scores)
        oppScore  = max(scores)
    
    return {"Team Score": teamScore, "Opp Score": oppScore}
    
    

def getSchedule(bsdata):
    scheduleSections = bsdata.findAll("section", {"class": "club-schedule"})
    scheduleData = []
    for scheduleSection in scheduleSections:
        uls = scheduleSection.findAll("ul")
        if len(uls) == 2:
            ul = uls[1]
            lis = ul.findAll('li')
            for li in lis:
                ref = li.find("a")
                if ref is None:
                    raise ValueError("There is no link in the schedule")
                gameRef  = ref.attrs['href']
                gameID = getGameID(gameRef)
                
                
                gameOpp = ref.find("div", {"class": "logo"})
                if gameOpp is None:
                    raise ValueError("There is no logo div in the schedule")
                opp = parseGameOpp(gameOpp)
                
                
                gameInfo = ref.find("div", {"class": "game-info"})
                if gameInfo is None:
                    raise ValueError("There is no game-info div in the schedule")
                info = parseGameInfo(gameInfo)
                
                
                gameResult = ref.find("div", {"class": "game-result"})
                if gameResult is not None:
                    result = parseGameResult(gameResult)
                else:
                    result = {"IsWin": None, "IsDone": False}
                    
                
                gameScore = ref.find("div", {"class": "score"})
                score = parseGameScore(gameScore, info, result, opp)
                    
                #print(opp,'\t',info,'\t',result,'\t',score)
                gameResult = {"GameID": gameID, "OppNo": opp}
                gameResult.update(info)
                gameResult.update(result)
                gameResult.update(score)
                scheduleData.append(gameResult)
                #print("")
                
        else:
            raise ValueError("Cannot parse schedule")
            
            
    return scheduleData


def getConference(bsdata):
    
    confData = {"Conference": None, "Teams": {}}
    standings = bsdata.find("article", {"class": "sub-module standings"})
    if standings is None:
        return confData
        raise ValueError("Could not find standings article!")
        
    h1 = standings.find("h1")
    if h1 is None:
        return confData
        raise ValueError("Could not find standings-conference article!")
    confText = h1.text
    confData = {"Conference": confText, "Teams": {}}
        
    table = standings.find("table", {"class": "mod-data"})
    if table is None:
        raise ValueError("Could not find standings-conference table!")
    trs = table.findAll("tr")
    
    headings = ["Name", "CONF", "GB", "OVR"]
    for tr in trs:
        tds = tr.findAll("td")
        if len(tds) == 4:
            confVals = [x.text for x in tds]
            confDatum = dict(zip(headings, confVals))
            teamID = getTeamID(tds[0].find("a").attrs['href'], -2)
            confData["Teams"][teamID] = confDatum
                        
    return confData


seasonData = {}
for teamID, teamData in teamsInfo.items():
    name = teamData["Name"]
    href = teamData["Ref"]
    print("==>",name)
    savename = "data/teams/{0}.p".format(name)
    
    bsdata     = getHTML(savename)    
    schedule   = getSchedule(bsdata)
    conference = getConference(bsdata)

    seasonData[teamID] = {"Name": name, "Ref": href, "Schedule": schedule, "Conference": conference}

print("Parsed {0} Division I Team Schedules".format(len(seasonData)))
saveFile(idata=seasonData, ifile="data/schedules.p", debug=True)

# %% [markdown]
# # Organize Team/Game Data

# %%
seasonData = getFile("data/schedules.p")

# %%
teamNameIDMap = {}

# %%
fullTeamData = {}
gamesData = {}
conferenceData = {}

# %%
for teamID, teamData in seasonData.items():
    name = teamData["Name"]
    ref  = teamData["Ref"]
    schedule   = teamData["Schedule"]
    conference = teamData["Conference"]
    
    teamNameIDMap[name] = teamID
    confName  = conference["Conference"]
    if confName is not None:
        confName  = confName.replace("Standings", "").strip()
        confName  = confName.replace("2019-20", "").strip()
    else:
        confName  = None
        
    confTeams = conference["Teams"]
    if confTeams is not None:
        confData = {k: v["Name"] for k,v in confTeams.items()}
    else:
        confData = None

    #conferenceData[teamID] = confName

    for gameData in schedule:
        gameID = gameData["GameID"]
        if gamesData.get(gameID) is not None:
            continue

        oppID  = gameData['OppNo']
        isHome = gameData["IsHomeGame"]
        isDone = gameData["IsDone"]
        if isDone is False or isDone is None:
            continue

        gameResult = {"ID": gameID}
        if isHome:
            gameResult["HomeTeam"] = teamID
            gameResult["AwayTeam"] = oppID
            gameResult["HomeTeamScore"] = gameData["Team Score"]
            gameResult["AwayTeamScore"] = gameData["Opp Score"]
        else:
            gameResult["HomeTeam"] = oppID
            gameResult["AwayTeam"] = teamID
            gameResult["HomeTeamScore"] = gameData["Opp Score"]
            gameResult["AwayTeamScore"] = gameData["Team Score"]

        gamesData[gameID] = gameResult
    fullTeamData[teamID] = {"Name": name, "Conference": confName}
    conferenceData[teamID] = {"Conference": confName}

# %%
gamesDF = DataFrame(gamesData).T
gamesDF.index.name = "GameID"
gamesDF = gamesDF.drop(["ID"], axis=1)
gamesDF.to_pickle("data/gamesDF.p")
gamesDF.to_csv("data/gamesDF.csv")

# %%
teamsDF = DataFrame(fullTeamData).T
teamsDF.index.name = "TeamID"
teamsDF.to_pickle("data/teamsDF.p")
teamsDF.to_csv("data/teamsDF.csv")

# %%
from pandas import DataFrame
# Out:
#                                 Name
# 261               Vermont Catamounts
# 2619           Stony Brook Seawolves
# 42                    Hartford Hawks
# 399               Albany Great Danes
# 2378                 UMBC Retrievers
# 160           New Hampshire Wildcats
# 2349        UMass Lowell River Hawks
# 311                Maine Black Bears
# 2066             Binghamton Bearcats
# 248                  Houston Cougars
# 2132             Cincinnati Bearcats
# 202           Tulsa Golden Hurricane
# 2724          Wichita State Shockers
# 2567                    SMU Mustangs
# 235                   Memphis Tigers
# 41                     UConn Huskies
# 218                      Temple Owls
# 2116                     UCF Knights
# 151            East Carolina Pirates
# 58               South Florida Bulls
# 2655               Tulane Green Wave
# 2168                   Dayton Flyers
# 227                Rhode Island Rams
# 179          St. Bonaventure Bonnies
# 257                 Richmond Spiders
# 2184                  Duquesne Dukes
# 2166               Davidson Wildcats
# 139            Saint Louis Billikens
# 2670                        VCU Rams
# 45       George Washington Colonials
# ...                              ...
# 326              Texas State Bobcats
# 2247          Georgia State Panthers
# 6              South Alabama Jaguars
# 290          Georgia Southern Eagles
# 2026  Appalachian State Mountaineers
# 250           UT Arlington Mavericks
# 2032       Arkansas State Red Wolves
# 324    Coastal Carolina Chanticleers
# 309          Louisiana Ragin' Cajuns
# 2433              UL Monroe Warhawks
# 2653                    Troy Trojans
# 2250                Gonzaga Bulldogs
# 252                      BYU Cougars
# 2608              Saint Mary's Gaels
# 279                   Pacific Tigers
# 2492                Pepperdine Waves
# 2539              San Francisco Dons
# 2541             Santa Clara Broncos
# 2351          Loyola Marymount Lions
# 301                San Diego Toreros
# 2501                 Portland Pilots
# 166          New Mexico State Aggies
# 2856      California Baptist Lancers
# 2547                Seattle Redhawks
# 292    UT Rio Grande Valley Vaqueros
# 2253          Grand Canyon Antelopes
# 140                   UMKC Kangaroos
# 2934     CSU Bakersfield Roadrunners
# 3084          Utah Valley Wolverines
# 2130           Chicago State Cougars
#
# [353 rows x 1 columns]

# %% [markdown]
# # Download Game Data

# %%
gamesData

# %%
#https://www.espn.com/mens-college-basketball/boxscore?gameId=401169817

# %%
for gameID in gamesData.keys():
    url="https://www.espn.com/mens-college-basketball/boxscore?gameId={0}".format(gameID)
    savename = "data/games/{0}.p".format(gameID)
    print("Downloading {0} Game Data".format(gameID))
    if not isFile(savename):
        try:
            getWebData(base=url, savename=savename, useSafari=False)
            sleep(2)
        except:
            print("Trouble with {0}".format(name))
            sleep(1)
# Out:
# Downloading 401170104 Game Data
# Downloading 401170985 Game Data
# Downloading 401170986 Game Data
# Downloading 401168458 Game Data
# Downloading 401168197 Game Data
# Downloading 401170987 Game Data
# Downloading 401183489 Game Data
# Downloading 401170988 Game Data
# Downloading 401170989 Game Data
# Downloading 401169454 Game Data
# Downloading 401170990 Game Data
# Downloading 401170991 Game Data
# Downloading 401170426 Game Data
# Downloading 401170211 Game Data
# Downloading 401170992 Game Data
# Downloading 401170979 Game Data
# Downloading 401170993 Game Data
# Downloading 401170845 Game Data
# Downloading 401170873 Game Data
# Downloading 401170921 Game Data
# Downloading 401170940 Game Data
# Downloading 401170962 Game Data
# Downloading 401170994 Game Data
# Downloading 401170923 Game Data
# Downloading 401170878 Game Data
# Downloading 401170964 Game Data
# Downloading 401170853 Game Data
# Downloading 401170982 Game Data
# Downloading 401170995 Game Data
# Downloading 401170967 Game Data
# Downloading 401168442 Game Data
# Downloading 401170968 Game Data
# Downloading 401170969 Game Data
# Downloading 401170970 Game Data
# Downloading 401170971 Game Data
# Downloading 401170972 Game Data
# Downloading 401170973 Game Data
# Downloading 401170974 Game Data
# Downloading 401170975 Game Data
# Downloading 401170976 Game Data
# Downloading 401168430 Game Data
# Downloading 401168264 Game Data
# Downloading 401170977 Game Data
# Downloading 401170978 Game Data
# Downloading 401170917 Game Data
# Downloading 401170959 Game Data
# Downloading 401170872 Game Data
# Downloading 401170980 Game Data
# Downloading 401170847 Game Data
# Downloading 401170941 Game Data
# Downloading 401170981 Game Data
# Downloading 401170943 Game Data
# Downloading 401170963 Game Data
# Downloading 401168346 Game Data
# Downloading 401168347 Game Data
# Downloading 401168348 Game Data
# Downloading 401166413 Game Data
# Downloading 401166422 Game Data
# Downloading 401166430 Game Data
# Downloading 401166433 Game Data
# Downloading 401166443 Game Data
# Downloading 401166449 Game Data
# Downloading 401166458 Game Data
# Downloading 401166464 Game Data
# Downloading 401166474 Game Data
# Downloading 401166495 Game Data
# Downloading 401166504 Game Data
# Downloading 401166510 Game Data
# Downloading 401166515 Game Data
# Downloading 401166519 Game Data
# Downloading 401166523 Game Data
# Downloading 401166526 Game Data
# Downloading 401166534 Game Data
# Downloading 401166540 Game Data
# Downloading 401166545 Game Data
# Downloading 401166551 Game Data
# Downloading 401166557 Game Data
# Downloading 401166561 Game Data
# Downloading 401166566 Game Data
# Downloading 401166572 Game Data
# Downloading 401166579 Game Data
# Downloading 401166582 Game Data
# ...
#   --> This file is 34.7kB.
# data/games/401175916.p size -> 35 kB
# Downloading 401175918 Game Data
#   --> This file is 34.2kB.
# data/games/401175918.p size -> 34 kB
# Downloading 401175919 Game Data
#   --> This file is 34.5kB.
# data/games/401175919.p size -> 35 kB
# Downloading 401175921 Game Data
#   --> This file is 34.4kB.
# data/games/401175921.p size -> 34 kB
# Downloading 401175910 Game Data
#   --> This file is 34.5kB.
# data/games/401175910.p size -> 34 kB
# Downloading 401175925 Game Data
#   --> This file is 34.1kB.
# data/games/401175925.p size -> 34 kB
# Downloading 401175926 Game Data
#   --> This file is 34.2kB.
# data/games/401175926.p size -> 34 kB
# Downloading 401175927 Game Data
#   --> This file is 34.3kB.
# data/games/401175927.p size -> 34 kB
# Downloading 401212056 Game Data
#   --> This file is 34.4kB.
# data/games/401212056.p size -> 34 kB
# Downloading 401174699 Game Data
#   --> This file is 34.7kB.
# data/games/401174699.p size -> 35 kB
# Downloading 401176039 Game Data
#   --> This file is 34.9kB.
# data/games/401176039.p size -> 35 kB
# Downloading 401175535 Game Data
#   --> This file is 34.6kB.
# data/games/401175535.p size -> 35 kB
# Downloading 401176040 Game Data
#   --> This file is 34.8kB.
# data/games/401176040.p size -> 35 kB
# Downloading 401172977 Game Data
#   --> This file is 35.1kB.
# data/games/401172977.p size -> 35 kB
# Downloading 401169863 Game Data
#   --> This file is 35.8kB.
# data/games/401169863.p size -> 36 kB
# Downloading 401176041 Game Data
#   --> This file is 34.1kB.
# data/games/401176041.p size -> 34 kB
# Downloading 401176042 Game Data
#   --> This file is 34.6kB.
# data/games/401176042.p size -> 35 kB
# Downloading 401176043 Game Data
#   --> This file is 34.7kB.
# data/games/401176043.p size -> 35 kB
# Downloading 401175948 Game Data
#   --> This file is 34.2kB.
# data/games/401175948.p size -> 34 kB
# Downloading 401175906 Game Data
#   --> This file is 34.1kB.
# data/games/401175906.p size -> 34 kB
# Downloading 401175993 Game Data
#   --> This file is 34.2kB.
# data/games/401175993.p size -> 34 kB
# Downloading 401176035 Game Data
#   --> This file is 34.1kB.
# data/games/401176035.p size -> 34 kB
# Downloading 401176005 Game Data
#   --> This file is 34.2kB.
# data/games/401176005.p size -> 34 kB
# Downloading 401175985 Game Data
#   --> This file is 34.2kB.
# data/games/401175985.p size -> 34 kB
# Downloading 401176047 Game Data
#   --> This file is 34.2kB.
# data/games/401176047.p size -> 34 kB
# Downloading 401176048 Game Data
#   --> This file is 34.4kB.
# data/games/401176048.p size -> 34 kB
# Downloading 401212055 Game Data
#   --> This file is 34.3kB.
# data/games/401212055.p size -> 34 kB
# Downloading 401173618 Game Data
#   --> This file is 35.0kB.
# data/games/401173618.p size -> 35 kB
# Downloading 401172820 Game Data
#   --> This file is 34.6kB.
# data/games/401172820.p size -> 35 kB
# Downloading 401186193 Game Data
#   --> This file is 35.0kB.
# data/games/401186193.p size -> 35 kB
# Downloading 401186436 Game Data
#   --> This file is 35.0kB.
# data/games/401186436.p size -> 35 kB
# Downloading 401175771 Game Data
#   --> This file is 35.0kB.
# data/games/401175771.p size -> 35 kB
# Downloading 401175947 Game Data
#   --> This file is 34.2kB.
# data/games/401175947.p size -> 34 kB
# Downloading 401175908 Game Data
#   --> This file is 34.5kB.
# data/games/401175908.p size -> 34 kB
# Downloading 401175973 Game Data
#   --> This file is 34.0kB.
# data/games/401175973.p size -> 34 kB
# Downloading 401175974 Game Data
#   --> This file is 34.1kB.
# data/games/401175974.p size -> 34 kB
# Downloading 401175975 Game Data
#   --> This file is 34.0kB.
# data/games/401175975.p size -> 34 kB
# Downloading 401175976 Game Data
#   --> This file is 34.1kB.
# data/games/401175976.p size -> 34 kB
# Downloading 401175897 Game Data
#   --> This file is 34.6kB.
# data/games/401175897.p size -> 35 kB
# Downloading 401169815 Game Data
#   --> This file is 36.0kB.
# data/games/401169815.p size -> 36 kB
# Downloading 401175898 Game Data
#   --> This file is 34.6kB.
# data/games/401175898.p size -> 35 kB
# Downloading 401172830 Game Data
#   --> This file is 35.1kB.
# data/games/401172830.p size -> 35 kB
# Downloading 401174463 Game Data
#   --> This file is 34.7kB.
# data/games/401174463.p size -> 35 kB
# Downloading 401171931 Game Data
#   --> This file is 34.9kB.
# data/games/401171931.p size -> 35 kB
# Downloading 401175899 Game Data
#   --> This file is 34.2kB.
# data/games/401175899.p size -> 34 kB
# Downloading 401175900 Game Data
#   --> This file is 34.9kB.
# data/games/401175900.p size -> 35 kB
# Downloading 401175901 Game Data
#   --> This file is 34.3kB.
# data/games/401175901.p size -> 34 kB
# Downloading 401175902 Game Data
#   --> This file is 34.6kB.
# data/games/401175902.p size -> 35 kB
# Downloading 401175903 Game Data
#   --> This file is 34.4kB.
# data/games/401175903.p size -> 34 kB
# Downloading 401175905 Game Data
#   --> This file is 34.5kB.
# data/games/401175905.p size -> 34 kB
# Downloading 401175913 Game Data
#   --> This file is 34.2kB.
# data/games/401175913.p size -> 34 kB
# Downloading 401173630 Game Data
#   --> This file is 34.8kB.
# data/games/401173630.p size -> 35 kB
# Downloading 401175118 Game Data
#   --> This file is 35.2kB.
# data/games/401175118.p size -> 35 kB
# Downloading 401173661 Game Data
#   --> This file is 35.6kB.
# data/games/401173661.p size -> 36 kB
# Downloading 401176008 Game Data
#   --> This file is 34.3kB.
# data/games/401176008.p size -> 34 kB
# Downloading 401176009 Game Data
#   --> This file is 34.9kB.
# data/games/401176009.p size -> 35 kB
# Downloading 401176010 Game Data
#   --> This file is 35.1kB.
# data/games/401176010.p size -> 35 kB
# Downloading 401174743 Game Data
#   --> This file is 34.9kB.
# data/games/401174743.p size -> 35 kB
# Downloading 401176011 Game Data
#   --> This file is 34.7kB.
# data/games/401176011.p size -> 35 kB
# Downloading 401170632 Game Data
#   --> This file is 35.0kB.
# data/games/401170632.p size -> 35 kB
# Downloading 401173560 Game Data
#   --> This file is 35.3kB.
# data/games/401173560.p size -> 35 kB
# Downloading 401176012 Game Data
#   --> This file is 34.9kB.
# data/games/401176012.p size -> 35 kB
# Downloading 401175992 Game Data
#   --> This file is 34.3kB.
# data/games/401175992.p size -> 34 kB
# Downloading 401176034 Game Data
#   --> This file is 34.4kB.
# data/games/401176034.p size -> 34 kB
# Downloading 401176003 Game Data
#   --> This file is 34.5kB.
# data/games/401176003.p size -> 34 kB
# Downloading 401175984 Game Data
#   --> This file is 34.5kB.
# data/games/401175984.p size -> 35 kB
# Downloading 401176036 Game Data
#   --> This file is 34.5kB.
# data/games/401176036.p size -> 35 kB
# Downloading 401175998 Game Data
#   --> This file is 34.2kB.
# data/games/401175998.p size -> 34 kB
# Downloading 401175740 Game Data
#   --> This file is 34.5kB.
# data/games/401175740.p size -> 35 kB
# Downloading 401175999 Game Data
#   --> This file is 34.4kB.
# data/games/401175999.p size -> 34 kB
# Downloading 401173662 Game Data
#   --> This file is 34.7kB.
# data/games/401173662.p size -> 35 kB
# Downloading 401176000 Game Data
#   --> This file is 34.5kB.
# data/games/401176000.p size -> 34 kB
# Downloading 401175742 Game Data
#   --> This file is 34.7kB.
# data/games/401175742.p size -> 35 kB
# Downloading 401176001 Game Data
#   --> This file is 34.7kB.
# data/games/401176001.p size -> 35 kB
# Downloading 401175805 Game Data
#   --> This file is 34.8kB.
# data/games/401175805.p size -> 35 kB
# Downloading 401182619 Game Data
#   --> This file is 35.1kB.
# data/games/401182619.p size -> 35 kB
# Downloading 401182621 Game Data
#   --> This file is 34.8kB.
# data/games/401182621.p size -> 35 kB
# Downloading 401175991 Game Data
#   --> This file is 34.1kB.
# data/games/401175991.p size -> 34 kB
# Downloading 401175983 Game Data
#   --> This file is 34.2kB.
# data/games/401175983.p size -> 34 kB
# Downloading 401176004 Game Data
#   --> This file is 34.4kB.
# data/games/401176004.p size -> 34 kB
# Downloading 401212058 Game Data
#   --> This file is 34.4kB.
# data/games/401212058.p size -> 34 kB
# Downloading 401175988 Game Data
#   --> This file is 34.3kB.
# data/games/401175988.p size -> 34 kB
# Downloading 401174703 Game Data
#   --> This file is 34.7kB.
# data/games/401174703.p size -> 35 kB
# Downloading 401175989 Game Data
#   --> This file is 34.5kB.
# data/games/401175989.p size -> 35 kB
# Downloading 401170518 Game Data
#   --> This file is 35.9kB.
# data/games/401170518.p size -> 36 kB
# Downloading 401183486 Game Data
#   --> This file is 35.4kB.
# data/games/401183486.p size -> 35 kB
# Downloading 401173636 Game Data
#   --> This file is 34.9kB.
# data/games/401173636.p size -> 35 kB
# Downloading 401175990 Game Data
#   --> This file is 34.8kB.
# data/games/401175990.p size -> 35 kB
# Downloading 401175982 Game Data
#   --> This file is 34.4kB.
# data/games/401175982.p size -> 34 kB
# Downloading 401175994 Game Data
#   --> This file is 34.2kB.
# data/games/401175994.p size -> 34 kB
# Downloading 401212057 Game Data
#   --> This file is 34.4kB.
# data/games/401212057.p size -> 34 kB
# Downloading 401169799 Game Data
#   --> This file is 35.7kB.
# data/games/401169799.p size -> 36 kB
# Downloading 401172328 Game Data
#   --> This file is 35.0kB.
# data/games/401172328.p size -> 35 kB
# Downloading 401175977 Game Data
#   --> This file is 34.8kB.
# data/games/401175977.p size -> 35 kB
# Downloading 401173060 Game Data
#   --> This file is 35.2kB.
# data/games/401173060.p size -> 35 kB
# Downloading 401170079 Game Data
#   --> This file is 35.2kB.
# data/games/401170079.p size -> 35 kB
# Downloading 401172979 Game Data
#   --> This file is 34.9kB.
# data/games/401172979.p size -> 35 kB
# Downloading 401173001 Game Data
#   --> This file is 34.8kB.
# data/games/401173001.p size -> 35 kB
# Downloading 401175978 Game Data
#   --> This file is 34.9kB.
# data/games/401175978.p size -> 35 kB
# Downloading 401175979 Game Data
#   --> This file is 35.3kB.
# data/games/401175979.p size -> 35 kB
# Downloading 401175986 Game Data
#   --> This file is 34.2kB.
# data/games/401175986.p size -> 34 kB
# Downloading 401176052 Game Data
#   --> This file is 34.9kB.
# data/games/401176052.p size -> 35 kB
# Downloading 401176053 Game Data
#   --> This file is 34.4kB.
# data/games/401176053.p size -> 34 kB
# Downloading 401170074 Game Data
#   --> This file is 35.1kB.
# data/games/401170074.p size -> 35 kB
# Downloading 401182615 Game Data
#   --> This file is 34.8kB.
# data/games/401182615.p size -> 35 kB
# Downloading 401173950 Game Data
#   --> This file is 34.7kB.
# data/games/401173950.p size -> 35 kB
# Downloading 401176054 Game Data
#   --> This file is 34.7kB.
# data/games/401176054.p size -> 35 kB
# Downloading 401175053 Game Data
#   --> This file is 34.7kB.
# data/games/401175053.p size -> 35 kB
# Downloading 401169884 Game Data
#   --> This file is 35.8kB.
# data/games/401169884.p size -> 36 kB
# Downloading 401175117 Game Data
#   --> This file is 34.3kB.
# data/games/401175117.p size -> 34 kB
# Downloading 401172561 Game Data
#   --> This file is 34.7kB.
# data/games/401172561.p size -> 35 kB
# Downloading 401175036 Game Data
#   --> This file is 35.0kB.
# data/games/401175036.p size -> 35 kB
# Downloading 401172576 Game Data
#   --> This file is 34.9kB.
# data/games/401172576.p size -> 35 kB
# Downloading 401175125 Game Data
#   --> This file is 34.4kB.
# data/games/401175125.p size -> 34 kB
# Downloading 401186455 Game Data
#   --> This file is 34.7kB.
# data/games/401186455.p size -> 35 kB
# Downloading 401173580 Game Data
#   --> This file is 34.7kB.
# data/games/401173580.p size -> 35 kB
# Downloading 401175131 Game Data
#   --> This file is 34.8kB.
# data/games/401175131.p size -> 35 kB
# Downloading 401175132 Game Data
#   --> This file is 34.9kB.
# data/games/401175132.p size -> 35 kB
# Downloading 401172624 Game Data
#   --> This file is 34.8kB.
# data/games/401172624.p size -> 35 kB
# Downloading 401172517 Game Data
#   --> This file is 34.2kB.
# data/games/401172517.p size -> 34 kB
# Downloading 401175135 Game Data
#   --> This file is 34.4kB.
# data/games/401175135.p size -> 34 kB
# Downloading 401175136 Game Data
#   --> This file is 34.6kB.
# data/games/401175136.p size -> 35 kB
# Downloading 401172495 Game Data
#   --> This file is 33.9kB.
# data/games/401172495.p size -> 34 kB
# Downloading 401174450 Game Data
#   --> This file is 34.5kB.
# data/games/401174450.p size -> 34 kB
# Downloading 401174468 Game Data
#   --> This file is 34.3kB.
# data/games/401174468.p size -> 34 kB
# Downloading 401172471 Game Data
#   --> This file is 34.2kB.
# data/games/401172471.p size -> 34 kB
# Downloading 401175141 Game Data
#   --> This file is 34.3kB.
# data/games/401175141.p size -> 34 kB
# Downloading 401175143 Game Data
#   --> This file is 34.0kB.
# data/games/401175143.p size -> 34 kB
# Downloading 401175144 Game Data
#   --> This file is 34.0kB.
# data/games/401175144.p size -> 34 kB
# Downloading 401172525 Game Data
#   --> This file is 34.3kB.
# data/games/401172525.p size -> 34 kB
# Downloading 401172502 Game Data
#   --> This file is 34.2kB.
# data/games/401172502.p size -> 34 kB
# Downloading 401175147 Game Data
#   --> This file is 34.2kB.
# data/games/401175147.p size -> 34 kB
# Downloading 401174472 Game Data
#   --> This file is 34.2kB.
# data/games/401174472.p size -> 34 kB
# Downloading 401174457 Game Data
#   --> This file is 34.5kB.
# data/games/401174457.p size -> 34 kB
# Downloading 401175149 Game Data
#   --> This file is 34.3kB.
# data/games/401175149.p size -> 34 kB
# Downloading 401172481 Game Data
#   --> This file is 34.3kB.
# data/games/401172481.p size -> 34 kB
# Downloading 401175114 Game Data
#   --> This file is 34.6kB.
# data/games/401175114.p size -> 35 kB
# Downloading 401169809 Game Data
#   --> This file is 35.2kB.
# data/games/401169809.p size -> 35 kB
# Downloading 401175120 Game Data
#   --> This file is 34.6kB.
# data/games/401175120.p size -> 35 kB
# Downloading 401175122 Game Data
#   --> This file is 34.7kB.
# data/games/401175122.p size -> 35 kB
# Downloading 401172587 Game Data
#   --> This file is 34.7kB.
# data/games/401172587.p size -> 35 kB
# Downloading 401175126 Game Data
#   --> This file is 34.7kB.
# data/games/401175126.p size -> 35 kB
# Downloading 401175127 Game Data
#   --> This file is 34.3kB.
# data/games/401175127.p size -> 34 kB
# Downloading 401169866 Game Data
#   --> This file is 35.2kB.
# data/games/401169866.p size -> 35 kB
# Downloading 401172604 Game Data
#   --> This file is 34.8kB.
# data/games/401172604.p size -> 35 kB
# Downloading 401174067 Game Data
#   --> This file is 34.4kB.
# data/games/401174067.p size -> 34 kB
# Downloading 401173558 Game Data
#   --> This file is 34.8kB.
# data/games/401173558.p size -> 35 kB
# Downloading 401175133 Game Data
#   --> This file is 34.6kB.
# data/games/401175133.p size -> 35 kB
# Downloading 401175134 Game Data
#   --> This file is 34.3kB.
# data/games/401175134.p size -> 34 kB
# Downloading 401172518 Game Data
#   --> This file is 34.4kB.
# data/games/401172518.p size -> 34 kB
# Downloading 401172494 Game Data
#   --> This file is 34.2kB.
# data/games/401172494.p size -> 34 kB
# Downloading 401175137 Game Data
#   --> This file is 34.3kB.
# data/games/401175137.p size -> 34 kB
# Downloading 401174467 Game Data
#   --> This file is 33.9kB.
# data/games/401174467.p size -> 34 kB
# Downloading 401174451 Game Data
#   --> This file is 34.5kB.
# data/games/401174451.p size -> 35 kB
# Downloading 401175139 Game Data
#   --> This file is 34.3kB.
# data/games/401175139.p size -> 34 kB
# Downloading 401172472 Game Data
#   --> This file is 34.4kB.
# data/games/401172472.p size -> 34 kB
# Downloading 401172524 Game Data
#   --> This file is 34.0kB.
# data/games/401172524.p size -> 34 kB
# Downloading 401175145 Game Data
#   --> This file is 34.2kB.
# data/games/401175145.p size -> 34 kB
# Trouble with Chicago State Cougars
# Downloading 401175146 Game Data
#   --> This file is 34.1kB.
# data/games/401175146.p size -> 34 kB
# Trouble with Chicago State Cougars
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-38d2c2e979ce> in <module>
#       7             getWebData(base=url, savename=savename, useSafari=False)
# ----> 8             sleep(2)
#       9         except:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-38d2c2e979ce> in <module>
#       9         except:
#      10             print("Trouble with {0}".format(name))
# ---> 11             sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Parse Game Data

# %%
for gameID in gamesData.keys():    
    savename = "data/games/{0}.p".format(gameID)
    bsdata = getHTML(savename)
    break

# %%
gameStats = {}

div = bsdata.find("div", {"data-module": "boxscore"})
if div is None:
    raise ValueError("There is no box score!")
    
    
teamNames = div.findAll("div", {"class": "team-name"})
teamIDs = []
for teamName in teamNames:
    img = teamName.find("img")
    if img is None:
        teamID = None
    else:
        src = img.attrs['src']
        try:
            vals = src.split(".png")
        except:
            raise ValueError("Cannot parse opponent src")
    
        teamID = getTeamID(vals[0], -1)
    teamIDs.append(teamID)

    
tables = div.findAll("table", {"class": "mod-data"})
for i,table in enumerate(tables):
    teamID = teamIDs[i]
    teamGameResults = {}
    
    headers = table.findAll("th")
    headers = [x.text for x in headers]
    players = table.findAll("tr")
    teamPlayers = []
    for player in players:
        tds = player.findAll("td")
        if len(tds) != 14:
            continue
            
        ## 1st entry is name/id
        name  = tds[0]
        if name.text == "TEAM":
            tds = [x.text for x in tds[2:]]
            teamData = dict(zip(headers[2:14], tds))
            for k in teamData.keys():
                val = teamData[k]
                if len(val.split('-')) == 1:
                    try:
                        val = int(val)
                    except:
                        raise ValueError("Could not convert {0} to an integer".format(val))
                else:
                    try:
                        val = [int(v) for v in val.split('-')]
                    except:
                        raise ValueError("Could not convert {0} to an integers".format(val))
                teamData[k] = val
            
            teamGameResults["Team"] = teamData
            teamGameResults["Players"] = teamPlayers
            gameStats[teamID] = teamGameResults
            
            
            ### Now go on to the next team
            continue
            
            
        url   = name.find('a').attrs['href']
        pid   = getTeamID(url, -2)
        spans = name.findAll("span")
        playerName = spans[0].text
        playerPos  = spans[2].text
        tds = [x.text for x in tds[1:]]
        #playerValues = [{"Name": playerName, "Pos": playerPos}] + 
        playerValues = tds
        if len(teamPlayers) <= 4:
            playerData = dict(zip(headers[1:14], playerValues))
        else:
            playerData = dict(zip(headers[15:], playerValues))
            
        for k in playerData.keys():
            val = playerData[k]
            if len(val.split('-')) == 1:
                try:
                    val = int(val)
                except:
                    raise ValueError("Could not convert {0} to an integer".format(val))
            else:
                try:
                    val = [int(v) for v in val.split('-')]
                except:
                    raise ValueError("Could not convert {0} to an integers".format(val))
            playerData[k] = val
        playerData["Name"] = playerName
        playerData["Position"] = playerPos
        playerData["ID"] = pid
        if len(teamPlayers) <= 4:
            playerData["Status"] = "Starter"
        else:
            playerData["Status"] = "Bench"
            

        
        teamPlayers.append(playerData)
            
    break

# %%
gameStats.keys()

# %%
    def downloadTeamStatisticsDataByYear(self, idval, name, year, debug=False):
        baseurl  = self.getBase()
        suburl   = "college-football/team/stats/_/id/{0}/season".format(idval)
        url      = join(baseurl, suburl, str(year))
        
        outputdir = self.getYearlyStatisticsDir(year)
        savename  = setFile(outputdir, "{0}-{1}.p".format(name, year))
        if isFile(savename):
            return
        
        if debug:
            print("Downloading {0} to {1}".format(url, savename))
        getWebData(base=url, savename=savename, useSafari=False)
        sleep(15+2*random())

# %%
                        
         
    ############################################################################################################
    # Team Games
    ############################################################################################################   
    def downloadGameDataByID(self, gameID, year, test=False, debug=False):        
        gamesDir   = self.getYearlyGamesDir(year)
        url="http://www.espn.com/college-football/playbyplay?gameId={0}".format(gameID)
        savename = setFile(gamesDir, "{0}.p".format(gameID))

        if isFile(savename):
            from os.path import getsize                    
            size = round(getsize(savename)/1e3)
            if size < 1:
                removeFile(savename, debug=True)

        if test:
            print("Downloading {0} to {1}".format(url,savename))
            return
        getWebData(base=url, savename=savename, dtime=6, useSafari=True, debug=True)
        sleep(6)
            
            
    def downloadGameData(self, debug=False, verydebug=False):
        resultsDir = self.getSeasonResultsDir()
        files = findExt(resultsDir, ext=".p", debug=False)

        gameType = "playbyplay"
        print("Sleeping for 5 seconds...")
        sleep(5)

        
        for ifile in files:
            seasonData = getFile(ifile)
            year       = seasonData.getYear()
            if year not in [2013,2014,2015]:
                continue
            gamesDir   = self.getYearlyGamesDir(year)
            
            teams = seasonData.teams
            for teamID,teamData in teams.items():
                teamGames = teamData.games
                for gameData in teamGames:
                    gameResult = gameData["Result"]
                    gameObject = gameData["Game"]
                    gameID     = gameObject.gameID
                    
                    if False:
                        prevLocation = "/Volumes/Seagate/Football/Games/Plays/{0}.html".format(gameID)
                        if isFile(prevLocation):
                            savename = setFile(gamesDir, "{0}.p".format(gameID))
                            if not isFile(savename) or True:
                                data = open(prevLocation, "rb").read()
                                saveFile(idata=data, ifile=savename, debug=True)
                                continue
                        continue

                    self.downloadGameDataByID(gameID, year, debug)
